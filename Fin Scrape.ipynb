# %%
from stocksymbol import StockSymbol

api_key = "ac9647da-71ac-4877-b559-1955796e3c17"
ss = StockSymbol(api_key)

# %%
# show a list of available market
market_list = ss.market_list

market_list
# Out:
# [{'market': 'venezuela',
#   'abbreviation': 've',
#   'totalCount': 25,
#   'lastUpdated': '2022-01-10T00:00:00.000Z',
#   'index': []},
#  {'market': 'southafrica',
#   'abbreviation': 'za',
#   'totalCount': 455,
#   'lastUpdated': '2022-01-10T00:00:00.000Z',
#   'index': []},
#  {'market': 'singapore',
#   'abbreviation': 'sg',
#   'totalCount': 540,
#   'lastUpdated': '2022-01-10T00:00:00.000Z',
#   'index': [{'id': 'TVC:STI', 'name': 'STRAITS TIMES INDEX'}]},
#  {'market': 'thailand',
#   'abbreviation': 'th',
#   'totalCount': 1562,
#   'lastUpdated': '2022-01-10T00:00:00.000Z',
#   'index': [{'id': 'SET:SET100', 'name': 'SET100 INDEX'},
#    {'id': 'SET:SET50', 'name': 'SET50 INDEX'}]},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'totalCount': 449,
#   'lastUpdated': '2022-01-10T00:00:00.000Z',
#   'index': [{'id': 'BIST:XUTUM', 'name': 'BIST TUM'},
#    {'id': 'BIST:XUTEK', 'name': 'BIST TEKNOLOJI'},
#    {'id': 'BIST:XU100', 'name': 'BIST 100'},
# ...

# %%
# get symbol list based on market
symbol_list_us = ss.get_symbol_list(market="US") # "us" or "america" will also work

# %%
 # get symbol only
symbol_only_list = ss.get_symbol_list(market="brazil", symbols_only=True)

print(symbol_only_list, sep=",")
# Out:
# ['AAPL34.SA', 'MSFT34.SA', 'GOGL34.SA', 'GOGL35.SA', 'AMZO34.SA', 'TSLA34.SA', 'FBOK34.SA', 'BERK34.SA', 'NVDC34.SA', 'H1SB34.SA', 'VISA34.SA', 'JNJB34.SA', 'UNHH34.SA', 'HOME34.SA', 'WALM34.SA', 'PGCO34.SA', 'MSCD34.SA', 'PFIZ34.SA', 'EXXO34.SA', 'DISB34.SA', 'COCA34.SA', 'CSCO34.SA', 'AVGO34.SA', 'LILY34.SA', 'NIKE34.SA', 'NFLX34.SA', 'ADBE34.SA', 'CHVX34.SA', 'PEPB34.SA', 'ABTT34.SA', 'ACNB34.SA', 'TMOS34.SA', 'ABBV34.SA', 'COWC34.SA', 'ORCL34.SA', 'VERZ34.SA', 'CMCS34.SA', 'SSFO34.SA', 'ULEV34.SA', 'PYPL34.SA', 'WFCO34.SA', 'ITLC34.SA', 'DHER34.SA', 'N1VS34.SA', 'MRCK34.SA', 'QCOM34.SA', 'MCDC34.SA', 'UPSS34.SA', 'ATTB34.SA', 'RDSA35.SA', 'SCHW34.SA', 'LOWC34.SA', 'L1IN34.SA', 'NEXT34.SA', 'TEXA34.SA', 'UPAC34.SA', 'INTU34.SA', 'A1MD34.SA', 'N1VO34.SA', 'GSGI34.SA', 'PHMO34.SA', 'RDSA34.SA', 'JDCO34.SA', 'HONB34.SA', 'S2HO34.SA', 'MDTC34.SA', 'BMYB34.SA', 'CVSH34.SA', 'T1MU34.SA', 'BLAK34.SA', 'RYTT34.SA', 'AXPB34.SA', 'A1MT34.SA', 'AMGN34.SA', 'ELCI34.SA', 'BOAC34.SA', 'SBUB34.S
# ...

# %%
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf


# test = symbol_only_list


msft = yf.Ticker("msft")

# get all stock info
msft.info

# for ticker in test:

#     try:
#         marketCap = pdr.get_quote_yahoo(ticker)['marketCap']
#         print("marketCap", marketCap)
#     except:
#         print('Error with: ', ticker)
#     try:
#         volume = pdr.get_quote_yahoo(ticker)['averageDailyVolume3Month']
#         print("AvgVolume", volume)  
#     except:
#         print('Error with: ', ticker)
#     try:
#         shares = pdr.get_quote_yahoo(ticker)['sharesOutstanding']
#         print("OutstandingShares", shares) 
#     except:
#         print('Error with: ', ticker)
#     try:
#         currency = pdr.get_quote_yahoo(ticker)['currency']
#         print("Currency:", currency)  
#     except:
#         print('Error with: ', ticker)
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'fax': '425 706 7329',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software—Infrastructure',
#  'sector': 'Technology',
# ...

# %%
import pandas as pd
import yfinance as yf



symbols = symbol_only_list
for symbol in symbols:
    stock = yf.Ticker(symbol)
    try:
        if stock.info['sector']:
            print(stock.info['symbol'] + ":" + str(stock.info['totalRevenue']))
    except:
        print('Error with: ', symbol)
# Out:
# AAPL34.SA:387537010688
# MSFT34.SA:204093997056
# GOGL34.SA:282836008960
# GOGL35.SA:282836008960
# AMZO34.SA:513982988288
# TSLA34.SA:81462001664
# Error with:  FBOK34.SA
# BERK34.SA:302089011200
# NVDC34.SA:26973999104
# H1SB34.SA:50512998400
# VISA34.SA:30186999808
# JNJB34.SA:94943002624
# UNHH34.SA:335943991296
# HOME34.SA:157403004928
# WALM34.SA:611289006080
# PGCO34.SA:80281001984
# MSCD34.SA:22236999680
# PFIZ34.SA:100329996288
# EXXO34.SA:402217009152
# DISB34.SA:84414996480
# COCA34.SA:43003998208
# CSCO34.SA:53161000960
# AVGO34.SA:34411999232
# LILY34.SA:28541399040
# NIKE34.SA:50625998848
# NFLX34.SA:31615549440
# ADBE34.SA:17998999552
# CHVX34.SA:244302004224
# PEPB34.SA:86391996416
# ABTT34.SA:43653001216
# ACNB34.SA:63144419328
# TMOS34.SA:44914999296
# ABBV34.SA:58054000640
# COWC34.SA:234389995520
# ORCL34.SA:47957999616
# VERZ34.SA:136834998272
# CMCS34.SA:121427001344
# SSFO34.SA:31352000512
# ULEV34.SA:60073000960
# PYPL34.SA:27517999104
# WFCO34.SA:73254002688
# ...
